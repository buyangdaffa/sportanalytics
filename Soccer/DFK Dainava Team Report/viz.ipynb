# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import chardet

# %%
df = pd.read_csv('TeamStatsDainava.csv')
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 df = pd.read_csv('TeamStatsDainava.csv')
#
# File c:\Users\Buyang Daffa\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File c:\Users\Buyang Daffa\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# ...

# %%
df
# Out:
#                   Date           Opponent    Score        Competition  \
# 0              Dainava            Average  Average  Lithuania. A Lyga
# 1  2023-03-18 00:00:00              Banga      2:1  Lithuania. A Lyga
# 2  2023-03-15 00:00:00           Riteriai      0:0  Lithuania. A Lyga
# 3  2023-03-12 00:00:00    Džiugas Telšiai      0:1  Lithuania. A Lyga
# 4  2023-03-04 00:00:00  Hegelmann Litauen      3:0  Lithuania. A Lyga
#
#    Duration   Scheme  Goals      xG  Shots  Shots on Target  ...  Throw Ins  \
# 0        96  4-1-4-1   0.75  1.3125  14.25             5.25  ...      25.25
# 1        96  4-1-4-1   2.00  1.0200  12.00             5.00  ...      25.00
# 2        95    5-4-1   0.00  0.9600  19.00             5.00  ...      25.00
# 3        95  4-1-4-1   1.00  2.1200  18.00             9.00  ...      29.00
# 4        98  4-1-4-1   0.00  1.1500   8.00             2.00  ...      22.00
#
#    Throw Ins Successful  Throw Ins Successful, %  Goal kicks  Match tempo  \
# ...

# %%
plt.stackplot(df['Opponent'], df['Goals'], df['xG'], labels=['Goals', 'xG'])
plt.legend(loc='upper left')
plt.title('Goals vs. xG')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\Buyang Daffa\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File c:\Users\Buyang Daffa\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File c:\Users\Buyang Daffa\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Opponent'
#
# ...

# %%
df = df.astype(int)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 df = df.astype(int)
#
# File c:\Users\Buyang Daffa\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\generic.py:6240, in NDFrame.astype(self, dtype, copy, errors)
#    6233     results = [
#    6234         self.iloc[:, i].astype(dtype, copy=copy)
#    6235         for i in range(len(self.columns))
#    6236     ]
#    6238 else:
#    6239     # else, only a single dtype is given
# -> 6240     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6241     return self._constructor(new_data).__finalize__(self, method="astype")
#    6243 # GH 33113: handle empty frame or series
#
# File c:\Users\Buyang Daffa\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\internals\managers.py:448, in BaseBlockManager.astype(self, dtype, copy, errors)
# ...
